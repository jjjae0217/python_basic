# %%
def add(a, b):
    return a + b

add2 = add

print(add)
print(add2)



print(add(1, 3))
r1 = add(10, 20)
print(r1 * 100)

r2 = add2("abc", "xyz")
print(r2)

def test():
    pass

r3 = test()
print(r3)


# def - 함수를 정의하는 키워드
# add - 함수 이름
# (a, b) - 매개변수(Parameter)
# : - 함수 코드블록의 시작
# return - 결과(객체)를 호출한 곳으로 반환
# Out:
# <function add at 0x00000216E62EAAC0>
# <function add at 0x00000216E62EAAC0>
# 4
# 3000
# abcxyz
# None

# %%
if True:
    x = 10

print(x)
# Out:
# 10

# %%
result = add(10, 20)
print(result)

# 10, 20 - 인수(Argument)
# add(10, 20) - 함수 호출
# result 에는 함수 호출식의 반환값을 대입
# Out:
# 30

# %%
if True:
    x = 10

print(x)

def test(): #지역변수 : a(매개변수), x
    x = 100
    print(x)

test()

print(x)   # NameError
# Out:
# 10
# 100
# 10

# %%
for i in range(3):
    value = i * 10

print(i)
print(value)
# Out:
# 2
# 20

# %%
try:
    result = 100 / 10
except:
    pass

print(result)
# Out:
# 10.0

# %%
name = "smith" # 길이
print(len(name))

# 오프셋(인덱싱)
print(name[2]) #i

print(name[1:3]) # 잘린값을 반환, 원본이 잘리는게 아니다.

for ch in name:
    print(ch)
# Out:
# 5
# i
# mi
# s
# m
# i
# t
# h

# %%
# 시퀀스[start:stop:step]
s = "python"

print(s[0:3])
print(s[2:5])
print(s[::-1])
# Out:
# pyt
# tho
# nohtyp

# %%
a = "py"
b = "thon"
print(a + b)
# Out:
# python

# %%
print("ha" * 3)
# Out:
# hahaha

# %%
print("py" in "python")
print("java" not in "python")
# Out:
# True
# True

# %%
print(len("python"))
# Out:
# 6

# %%
s = "python"
print(s[0])
s[0] = "C" # error
# Out:
# p
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 s = "python"
#       2 print(s[0])
# ----> 3 s[0] = "C" # error
#
# TypeError: 'str' object does not support item assignment

# %%
nums = [1, 2, 3]
nums[0] = 100
print(nums)
# Out:
# [100, 2, 3]

# %%
print('python')
print("python")

# 여려줄 문자열

text = '''
안녕하세요
파이썬입니다
'''
print(text)

text = """
안녕하세요
파이썬입니다
"""
print(text)

# 이스케이프 문자
print("Hello\nPython")

# Raw 문자열 : 문자열 안의 이스케이프 문자(\n, \t, \\ 등)를 특별하게 해석하지 않고 그대로 표현
print(r"C:\Users\data")

# f-string : 문자열 안에 변수 표현식{변수} 사용
name = "Tom"
print(f"이름은 {name}이다")
# Out:
# python
# python
#
# 안녕하세요
# 파이썬입니다
#
#
# 안녕하세요
# 파이썬입니다
#
# Hello
# Python
# C:\Users\data
# 이름은 Tom이다

# %%
name = "Tom"
print(f"이름은{name}이다")
print("이름은"+name+"이다")

age = 20
print("나이는"+str(age)+"입니다")
print(f"나이는(age)입니다")

#문자열 포멧방식
# Out:
# 이름은Tom이다
# 이름은Tom이다
# 나이는20입니다
# 나이는(age)입니다

# %%
year = 2026
month = 6
day = 22
date = year + "-" + month + "-" + day # TypeError: unsupported operand type(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 year = 2026
#       2 month = 6
#       3 day = 22
# ----> 4 date = year + "-" + month + "-" + day # TypeError: unsupported operand type(s)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
year = 2026
month = 6
day = 22

date = str(year) + "-" + str(month) + "-" + str(day)

print(date)
# Out:
# 2026-6-22

# %%
a = "123"
b = "10"

print(a + b) # 12310

result = int(a) + int(b)

print(result)
# Out:
# 12310
# 133

# %%
s = "python".upper()
print(s)
s2 = s.lower()
print(s2)
# Out:
# PYTHON
# python

# %%
s = "python"
print(dir(s))
print(s.upper())
print(s) #대부분의 객체 메서드는 자기자신은 수정, 문자열은 불씬
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# PYTHON
# ...

# %%
s = "python"
print(dir(s))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
text = "Python Programming"

print(text.upper())      # 모두 대문자
print(text.lower())      # 모두 소문자
print(text.capitalize()) # 첫 글자만 대문자
print(text.title())      # 각 단어 첫 글자 대문자
# Out:
# PYTHON PROGRAMMING
# python programming
# Python programming
# Python Programming

# %%
text = "   python   "

print(text.strip()) #양쪽 공백 제거
print(text.lstrip()) #왼쪽 공백 제거
print(text.rstrip()) #오른쪽 공백 제거
# Out:
# python
# python
#    python

# %%
text = "Python Programming"

print(text.find("Pro"))
print(text.find("Java")) # -1을 반환하면 글자를 찾지 못했을때
print(text.startswith("Python")) #startswith(a): a로 시작되는지 판별, True/False 변환, 상이"김" name,startsw
print(text.endswith("ing")) #endswith(a): a로 끝나는지 판별, True/False 변환, 파일중에 한글 파일반 f.endswith(".hwp")
# Out:
# 7
# -1
# True
# True

# %%
text = "I like Java"

print(text.replace("Java", "Python"))
# Out:
# I like Python

# %%
data = "apple,banana,orange"

result = data.split(",")

print(result) # ['apple', 'banana', 'orange']
# Out:
# ['apple', 'banana', 'orange']

# %%
fruits = ["apple", "banana", "orange"]

result = ", ".join(fruits)

print(result)
# Out:
# apple, banana, orange

# %%
text = "banana"

print(text.count("a")) # 3
print(text.count("na")) # 2
# Out:
# 3
# 2

# %%
print("123".isdigit())      # 문자열이 숫자로만 구성되어 있는가?
print("Python".isalpha())   # 문자열이 영문자(또는 한글 등 문자)로만 구성되어 있는가?
print("Python123".isalnum()) # 문자열이 문자와 숫자로만 구성되어 있는가?
# Out:
# True
# True
# True

# %%
num = "100"

print(num.zfill(5))    # 전체 길이가 5가 되도록 왼쪽을 0으로 채움
print(num.center(10))  # 전체 길이가 10이 되도록 가운데 정렬
print(num.ljust(10))   # 전체 길이가 10이 되도록 왼쪽 정렬
print(num.rjust(10))   # 전체 길이가 10이 되도록 오른쪽 정렬
# Out:
# 00100
#    100
# 100
#        100

# %%
phone1 = "010"
phone2 = "1234"
phone3 = "5678"

phone = "-".join([phone1, phone2, phone3])

print(phone)
# Out:
# 010-1234-5678

# %%
email = "python@test.com"

user_id = email.split("@")[0] #  # @를 기준으로 분리한 후 첫 번째 요소(인덱스 0) 추출

print(user_id)
# Out:
# python

# %%
filename = "report.xlsx"

ext = filename.split(".")[-1] # # .을 기준으로 분리한 후 마지막 요소(인덱스 -1) 추출

print(ext)
# Out:
# xlsx

# %%
# 1) 문자 채우기, 정렬
name = "Python"

print(f"{name:*<15}")  # 왼쪽 정렬, 빈칸은 *로 채움
print(f"{name:*^15}")  # 가운데 정렬, 빈칸은 *로 채움
print(f"{name:*>15}")  # 오른쪽 정렬, 빈칸은 *로 채움
# 변수 사용 가능
w = 15
print(f"{name:*>{w}}")  # 오른쪽 정렬, 빈칸은 *로 채움
# Out:
# Python*********
# ****Python*****
# *********Python
# *********Python

# %%
# 2) 숫자 채우기
num = 123

print(f"{num:08}")   # 전체 8자리 문자로 변경 후, 부족한 자리는 0으로 채움
print(f"{num:010}")
# Out:
# 00000123
# 0000000123

# %%
# 3) 부호 포함 출력
a = 150
b = -50

print(f"{a:+}")  # 문자열 변경시 양수는 +, 음수는 - 표시
print(f"{b:+}")    # 음수는 - 표시
# Out:
# +150
# -50

# %%
# 4) 양수는 공백, 음수만 부호 포함 출력
c = 100
d = -100

print(f"{c: }")   # 양수 앞에 공백
print(f"{d: }")   # 음수는 - 유지
# Out:
#  100
# -100

# %%
# 5) 천 단위 구분기호 출력
sales = 1234567890
print(f"{sales:,}")  # 천 단위마다 콤마 추가
# Out:
# 1,234,567,890

# %%
# 6) 천 단휘 구분기호 + 자릿수 맞춤
sales2 = 1234567
print(f"{sales2:>15,}")  # 오른쪽 정렬 + 천 단위 구분
print(f"{sales2:<15,}")  # 오른쪽 정렬 + 천 단위 구분
# Out:
#       1,234,567
# 1,234,567

# %%
# 7) 소수점 반올림
pi = 3.1415926535
print(f"{pi:.2f}")   # 소수점 둘째 자리까지 반올림 후 문자열 출력
print(f"{pi:.4f}")   # 소수점 넷째 자리까지
# Out:
# 3.14
# 3.1416

# %%
# 8) 지수 표기법
num = 123456789
print(f"{num:e}")  # 소문자 e 
# 1.234568e+08
print(f"{num:E}")  # 대문자 E
# 1.234568E+08
# Out:
# 1.234568e+08
# 1.234568E+08

# %%
# 9) 백분율 표시
rate = 0.8746
print(f"{rate:.0%}")  # 100을 곱하고 반올림
print(f"{rate:.1%}")  # 100을 곱하고 소수점 첫째 자리까지 반올림 % 표시
print(f"{rate:.2%}")

# 87%
# 87.5%
# 87.46%
# Out:
# 87%
# 87.5%
# 87.46%

# %%
# 10) 2진수, 8진수, 16진수 
num = 255
print(f"{num:b}")  # 11111111 2진수
print(f"{num:o}")  # 377      8진수
print(f"{num:x}")  # ff       16진수 소문자
print(f"{num:X}")  # FF       16진수 대문자
# Out:
# 11111111
# 377
# ff
# FF

# %%
# 11) 날짜 포맷팅
# 파이썬 언어에 포함된 객체/함수라도 내장객체/함수와 모듈안에 포함된 객체/함수로 구분된다.
# 모듈안에 포함된 것들은 import가 필요하다. 뒤에서 모듈수업때 설명
from datetime import datetime # datetime 모듈(module) 안에 있는 datetime 클래스(객체)를 가져온다.
today = datetime.now()
print(f"{today:%Y-%m-%d}")          # 연-월-일
print(f"{today:%H:%M:%S}")          # 시:분:초
print(f"{today:%Y/%m/%d %H:%M}")    # 날짜 + 시간
# 2026-06-22
# 19:48:14
# 2026/06/22 19:48
# Out:
# 2026-06-24
# 12:36:12
# 2026/06/24 12:36

# %%
# 12) 변수와 값을 같이 출력
name = "Kim"
age = 20
print(f"{name=}")  # 변수명=값
print(f"{age=}")
# Out:
# name='Kim'
# age=20

# %%
# 13) 계산결과
a = 10
b = 20
print(f"{a} + {b} = {a+b}")       # 계산식 결과 출력
print(f"{a*b=}")                  # 변수명 포함 출력
# Out:
# 10 + 20 = 30
# a*b=200

# %%
# 14) 표형태로 출력
name = "홍길동"
age = 25
score = 95.5

print(f"{'이름':<10}{'나이':<10}{'점수':<10}")
print(f"{name:<10}{age:<10}{score:<10.1f}")
# Out:
# 이름        나이        점수
# 홍길동       25        95.5

# %%
# 15) 복합
money = 3500000.75
print(f"{money:>15,.2f}")
# > : 오른쪽 정렬
# 15 : 전체 폭 15칸
# , : 천 단위 콤마
# .2f : 소수점 2자리 실수
# Out:
#    3,500,000.75

# %%
# 16) 보고서 형태
income = 123456789
expense = 98765432
profit = income - expense

print(f"{'매출':<10}: {income:>15,}")
print(f"{'비용':<10}: {expense:>15,}")
print(f"{'이익':<10}: {profit:>15,}")
# Out:
# 매출        :     123,456,789
# 비용        :      98,765,432
# 이익        :      24,691,357

# %%
# 1) 문자 채우기, 정렬
name = "Python"

print(f"{name:*<15}")  # 왼쪽 정렬, 빈칸은 *로 채움
print(f"{name:*^15}")  # 가운데 정렬, 빈칸은 *로 채움
print(f"{name:*>15}")  # 오른쪽 정렬, 빈칸은 *로 채움
# 변수 사용 가능
w = 15
print(f"{name:*>{w}}")  # 오른쪽 정렬, 빈칸은 *로 채움


# 2) 숫자 채우기
num = 123

print(f"{num:08}")   # 전체 8자리 문자로 변경 후, 부족한 자리는 0으로 채움
print(f"{num:010}")

# 3) 부호 포함 출력
a = 150
b = -50

print(f"{a:+}")  # 문자열 변경시 양수는 +, 음수는 - 표시
print(f"{b:+}")    # 음수는 - 표시

# 4) 양수는 공백, 음수만 부호 포함 출력
c = 100
d = -100

print(f"{c: }")   # 양수 앞에 공백
print(f"{d: }")   # 음수는 - 유지

# 5) 천 단위 구분기호 출력
sales = 1234567890
print(f"{sales:,}")  # 천 단위마다 콤마 추가

# 6) 천 단휘 구분기호 + 자릿수 맞춤
sales2 = 1234567
print(f"{sales2:>15,}")  # 오른쪽 정렬 + 천 단위 구분
print(f"{sales2:<15,}")  # 오른쪽 정렬 + 천 단위 구분

# 7) 소수점 반올림
pi = 3.1415926535
print(f"{pi:.2f}")   # 소수점 둘째 자리까지 반올림 후 문자열 출력
print(f"{pi:.4f}")   # 소수점 넷째 자리까지

# 8) 지수 표기법
num = 123456789
print(f"{num:e}")  # 소문자 e 
# 1.234568e+08
print(f"{num:E}")  # 대문자 E
# 1.234568E+08

# 9) 백분율 표시
rate = 0.8746
print(f"{rate:.0%}")  # 100을 곱하고 반올림
print(f"{rate:.1%}")  # 100을 곱하고 소수점 첫째 자리까지 반올림 % 표시
print(f"{rate:.2%}")

# 87%
# 87.5%
# 87.46%

# 10) 2진수, 8진수, 16진수 
num = 255
print(f"{num:b}")  # 11111111 2진수
print(f"{num:o}")  # 377      8진수
print(f"{num:x}")  # ff       16진수 소문자
print(f"{num:X}")  # FF       16진수 대문자

# 11) 날짜 포맷팅
# 파이썬 언어에 포함된 객체/함수라도 내장객체/함수와 모듈안에 포함된 객체/함수로 구분된다.
# 모듈안에 포함된 것들은 import가 필요하다. 뒤에서 모듈수업때 설명
from datetime import datetime # datetime 모듈(module) 안에 있는 datetime 클래스(객체)를 가져온다.
today = datetime.now()
print(f"{today:%Y-%m-%d}")          # 연-월-일
print(f"{today:%H:%M:%S}")          # 시:분:초
print(f"{today:%Y/%m/%d %H:%M}")    # 날짜 + 시간
# 2026-06-22
# 19:48:14
# 2026/06/22 19:48

# 12) 변수와 값을 같이 출력
name = "Kim"
age = 20
print(f"{name=}")  # 변수명=값
print(f"{age=}")

# 13) 계산결과
a = 10
b = 20
print(f"{a} + {b} = {a+b}")       # 계산식 결과 출력
print(f"{a*b=}")                  # 변수명 포함 출력

# 14) 표형태로 출력
name = "홍길동"
age = 25
score = 95.5

print(f"{'이름':<10}{'나이':<10}{'점수':<10}")
print(f"{name:<10}{age:<10}{score:<10.1f}")

# 15) 복합
money = 3500000.75
print(f"{money:>15,.2f}")
# > : 오른쪽 정렬
# 15 : 전체 폭 15칸
# , : 천 단위 콤마
# .2f : 소수점 2자리 실수

# 16) 보고서 형태
income = 123456789
expense = 98765432
profit = income - expense

print(f"{'매출':<10}: {income:>15,}")
print(f"{'비용':<10}: {expense:>15,}")
print(f"{'이익':<10}: {profit:>15,}")
# Out:
# Python*********
# ****Python*****
# *********Python
# *********Python
# 00000123
# 0000000123
# +150
# -50
#  100
# -100
# 1,234,567,890
#       1,234,567
# 1,234,567
# 3.14
# 3.1416
# 1.234568e+08
# 1.234568E+08
# 87%
# 87.5%
# 87.46%
# 11111111
# 377
# ff
# FF
# 2026-06-24
# 11:47:47
# 2026/06/24 11:47
# name='Kim'
# age=20
# 10 + 20 = 30
# a*b=200
# 이름        나이        점수
# 홍길동       25        95.5
#    3,500,000.75
# 매출        :     123,456,789
# 비용        :      98,765,432
# 이익        :      24,691,357

# %%
name = input("이름을 입력하세요: ") # 키보드로 입력한 문자열을 반환(엔트키 전)
print("당신의 이름은 " + name + "입니다.")
# Out:
# 당신의 이름은 정재입니다.

# %%
x = input("첫번째 숫자 입력")
y = input("두번째 숫자 입력")

result = int(x) + int(y)

print( result)
# Out:
# 5

# %%
print("hi","bye", sep="//")

# %%
name = "Park"
age = 30

# f-string 기본 사용
print(f"이름: {name}, 나이: {age}")  # 변수 값을 문자열 안에 직접 삽입

# 소수점 자리수 지정
pi = 3.141592
print(f"{pi:.2f}")  # 소수점 둘째 자리까지 출력 → 3.14

# 자리수(폭) 지정
num = 7
print(f"{num:5}")   # 전체 5칸 확보, 오른쪽 정렬 → '    7'
print(f"{num:05}")  # 빈칸을 0으로 채움 → 00007
# Out:
# 이름: Park, 나이: 30
# 3.14
#     7
# 00007

# %%
# 기본 사용
print("이름: {}, 나이: {}".format("Park", 30))  # {} 순서대로 값 들어감

# 인덱스 사용
print("이름: {0}, 나이: {1}".format("Park", 30))  # 번호로 위치 지정

# 이름 지정
print("이름: {name}, 나이: {age}".format(name="Park", age=30))  
# 변수 이름으로 직접 지정 가능
# Out:
# 이름: Park, 나이: 30
# 이름: Park, 나이: 30
# 이름: Park, 나이: 30

# %%
name = "Park"
age = 30

print("이름: %s, 나이: %d" % (name, age))  
# %s = 문자열, %d = 정수

pi = 3.141592
print("%.2f" % pi)  # 소수점 둘째 자리까지 출력 → 3.14
# Out:
# 이름: Park, 나이: 30
# 3.14

# %%
# 왼쪽 정렬 (<), 오른쪽 정렬 (>), 가운데 정렬 (^)
print(f"{'Python':<10}")  # 왼쪽 정렬
print(f"{'Python':>10}")  # 오른쪽 정렬
print(f"{'Python':^10}")  # 가운데 정렬
# Out:
# Python
#     Python
#   Python

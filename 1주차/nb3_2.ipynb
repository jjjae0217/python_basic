# %%
# 1. 산술 연산자

a = 5
b = 2

print(a + b)   #7 add(a, b)
print(a // b)  #2
print(a % b)   #1
print(5 ** 2)
# Out:
# 7
# 2
# 1
# 25

# %%
# 2. 비교 연산자 : 연산(표현식)의 결과가 True 또는 False로 반환된다.

print(5 > 3)      # True
print(5 == 3)     # False
# Out:
# True
# False

# %%
# 3. 논리 연산자

print(True and False)   # False
print(True or False)    # True
print(not True)         # False
# Out:
# False
# True
# False

# %%
4. 멤버십 연산자

print(3 in [1, 2, 3])       # True
a = [1, 2, 3]
print(4 in a)  # False
print(4 not in a)   # True
# Out:
# True
# False
# True

# %%
5. 식별 연산자

​두 변수가 같은 객체를 참조하는지 확인

a = [1, 2]
b = a

a is b      # True
a == b      # True
# Out:
# True

# %%
c = [1, 2]
d = [1, 2]

c is d      # False
c == d      # True

== : 객체의 값만 비교 

is : 객체 비교

​
# Out:
# True

# %%
​6. 삼항 연산자

score = 50
result = "합격" if score >= 60 else "불합격"
print(result)
# Out:
# 불합격

# %%
7. 대입 문

​대입연산자라고 보통 알고있지만, 파이썬에서는 연산은 값(객체)을 반환해야 하는데 
대입연산자들은 값(객체)를 반환하지 않기 때문에 정확히는 연산표현식이 아니고 변수에 객체를 대입하는 명령문(문)이다.  

a = 1
a = a + 5 # a+=5
print(a)
# Out:
# 6

# %%
a = 10

# a = a+ 5와 같은 표현(편한거 사용하면 된다) 
a += 5 
print(a)  # 15
# Out:
# 15

# %%
8. 월러스 연산자(대입 후 대입된 값을 반환하는 연산자) : python3.8 이후

​
파이썬에서는 다음과 같은 코드는 에러가 발생한다.

대입 연산자 우측에 표현(식)이 와야 하는데 우측 ()안에 대입문을 상용해서 에러 발생.

= 는 연산자(operator)가 아니라 대입문(statement) 이기 때문이다.

= : 대입문 → 값을 반환하지 않음 

:= : 대입 연산자 → 값을 반환함
n = 10
result = (x = n>5)   # 대입하면서 값
print(result)

:= 월러스 연산자 사용, result = 우측 표현식 자리에 대입문이 아닌 대입연산자(:=)를 사용 

월러스 연산자는 왼쪽변수에 우측 값을 할당하고 할당된 값을 반환하는 대입연산자이다.

​
# Out:
#   Cell In[11], line 2
#     result = (x = n>5)   # 대입하면서 값
#               ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
n = 10
result = (x = n>5)   # 대입하면서 값
print(result)
​
* 다른 언어에서는 다음과 같은 if문 표현식 자리에 =를  많이 사용하는데, 파이썬의 경우 표현식 자리에 =를 사용할 수 없기때문에 아래와 같은 표현은 에러가 발생한다.

# %%
n = 10
result = (x := n>5)   # 대입하면서 값 반환
print(result)
​

* 다른 언어에서는 다음과 같은 if문 표현식 자리에 =를  많이 사용하는데, 파이썬의 경우 표현식 자리에 =를 사용할 수 없기때문에 아래와 같은 표현은 에러가 발생한다

# %%
# s변수의 문자열의 길이가 5보다 크면 문자열 길이를 출력
s = "python"
if (n = len(s)) > 5:
    print(n)

python 3.8 이전에는 위와 같은 표현은 다음과 같이 구현했다.

# %%
s = "python"
n = len(s)
if n > 5:
    print(n)

python 3.8에서 월러스 연산자가 추가된 후에는 다음과 같은 구현 가능

# %%
s = "python"
if (n := len(s)) > 5:
    print(n)
